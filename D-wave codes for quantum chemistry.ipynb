# %% [markdown]
# # 2-electon system large-D with electric field and Z=2

# %%
import dimod
import neal
solver = neal.SimulatedAnnealingSampler()
import numpy as np
import math 
from scipy.optimize import minimize
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy.optimize import minimize, minimize_scalar
from scipy import integrate
# %matplotlib inline

Z=2
ub= -0.01
lb = 0.04

def objective(x,b):
    return (1/2)*((1/ x[0]**2)+ (1/ x[1]**2)) - Z*(1/ x[0]) - Z*(1/ x[1]) + (1/ math.sqrt(x[0]**2 + x[1]**2)) - (b*(x[0]) + b*(x[1]))


# initial guesses
i= 0.02
#j=1.2
n = 2
x0 = np.zeros(n)
x0[0] = 1.0
x0[1] = 5.0

# show initial objective
#print('Initial Objective: ' + str(objective(x0, i)))
#For j in np.arange(1.1,1.5, .1):

for i in np.arange(ub,lb, .0001):
        
    solution1 = minimize(objective,x0, i, method="Nelder-Mead")
    seed = solution1.x
    
    solution = minimize(objective,seed, i, method="Nelder-Mead")
    x = solution.x
    
    m= (x[1]-x[0])/x[1]
    
    h1 = (1/2)*(1/ x[0]**2) - (Z/ x[0])
    h2 =(1/2)* (1/ x[1]**2) - (Z/ x[1])
    #J =  (1/ math.sqrt(x[0]**2 + x[1]**2)) 
    J12=  (1/ math.sqrt(x[0]**2 + x[1]**2)) - (i*(x[0]) + i*(x[1]))
    energy = objective(x, i)
    #- (i*(x[0]) - i*(x[1]))
    #print(m)
    Norm = math.sqrt((h1)**2 + (h2)**2 + (J12)**2)
    norm_energy = (energy) / (Norm)
    m1 = h1 / (Norm)
    m2 = h2 / (Norm)
    m3 = J12 / (Norm)
    
    H1 = -(1/2)*(m1+(m3/2))
    H2 = -(1/2)*(m2+(m3/2))
    H3 =  m3/4
    I1 = (1/2)*(m1+m2+(m3/2))
    
    response = solver.sample_ising({'a': H1, 'b': H2}, {('a', 'b'): H3}, num_reads=1)
    energydwave= response.data_vectors['energy'] 
    #print(energy)
    
    m5 = I1+energydwave
    plt.figure(1)
    plt.scatter(i, m5)
    plt.xlabel(r'$\mathcal{E}$')
    plt.ylabel(r'$Normalized ~Energy ~D-wave$')
    plt.title(r'$Normalized~ Energy ~D-wave$ vs $\mathcal{E}$')
    plt.xlim(ub,lb)
    
    m4 = norm_energy
    plt.figure(2)
    plt.scatter(i, m4)
    plt.xlabel(r'$\mathcal{E}$')
    plt.ylabel(r'$Normalized ~Energy$')
    plt.title(r'$Normalized~ Energy$ vs $\mathcal{E}$')
    plt.xlim(ub,lb)
    
    #print(m1, m2, m3, i)
    
    #print(energydwave)

# %%
import dimod
import neal
solver = neal.SimulatedAnnealingSampler()
import numpy as np
import math 
from scipy.optimize import minimize
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy.optimize import minimize, minimize_scalar
from scipy import integrate
# %matplotlib inline

Z=2
ub= -0.01
lb = 0.04

def objective(x,b):
    return (1/2)*((1/ x[0]**2)+ (1/ x[1]**2)) - Z*(1/ x[0]) - Z*(1/ x[1]) + (1/ math.sqrt(x[0]**2 + x[1]**2)) - (b*(x[0]) + b*(x[1]))


# initial guesses
i= 0.02
#j=1.2
n = 2
x0 = np.zeros(n)
x0[0] = 1.0
x0[1] = 5.0

# show initial objective
#print('Initial Objective: ' + str(objective(x0, i)))
#For j in np.arange(1.1,1.5, .1):

for i in np.arange(ub,lb, .0001):
        
    solution1 = minimize(objective,x0, i, method="Nelder-Mead")
    seed = solution1.x
    
    solution = minimize(objective,seed, i, method="Nelder-Mead")
    x = solution.x
    
    #m= (x[1]-x[0])/x[1]
    
    h1 = (1/2)*(1/ x[0]**2) - (Z/ x[0])
    h2 =(1/2)* (1/ x[1]**2) - (Z/ x[1])
    #J =  (1/ math.sqrt(x[0]**2 + x[1]**2)) 
    J12=  (1/ math.sqrt(x[0]**2 + x[1]**2)) - (i*(x[0]) + i*(x[1]))
    energy = objective(x, i)
    #- (i*(x[0]) - i*(x[1]))
    #print(m)
    Norm = math.sqrt((h1)**2 + (h2)**2 + (J12)**2)
    norm_energy = (energy) / (Norm)
    m1 = h1 / (Norm)
    m2 = h2 / (Norm)
    m3 = J12 / (Norm)
    
    response = solver.sample_ising({'a': m1, 'b': m2}, {('a', 'b'): m3}, num_reads=1)
    energydwave= response.data_vectors['energy'] 
    #print(energy)
    
    m5 = energydwave
    plt.figure(1)
    plt.scatter(i, m5)
    plt.xlabel(r'$\mathcal{E}$')
    plt.ylabel(r'$Normalized ~Energy ~D-wave$')
    plt.title(r'$Normalized~ Energy ~D-wave$ vs $\mathcal{E}$')
    plt.xlim(ub,lb)
    
    m4 = norm_energy
    plt.figure(2)
    plt.scatter(i, m4)
    plt.xlabel(r'$\mathcal{E}$')
    plt.ylabel(r'$Normalized ~Energy$')
    plt.title(r'$Normalized~ Energy$ vs $\mathcal{E}$')
    plt.xlim(ub,lb)
    
    #print(m1, m2, m3, i)
    
    #print(energydwave)

# %% [markdown]
# # 2-electon system large-D with electric field and Z=3

# %%
import dimod
import neal
solver = neal.SimulatedAnnealingSampler()
import numpy as np
import math 
from scipy.optimize import minimize
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy.optimize import minimize, minimize_scalar
from scipy import integrate
# %matplotlib inline

Z=3
ub= 0.04
lb = 0.08

def objective(x,b):
    return (1/2)*((1/ x[0]**2)+ (1/ x[1]**2)) - Z*(1/ x[0]) - Z*(1/ x[1]) + (1/ math.sqrt(x[0]**2 + x[1]**2)) - (b*(x[0]) + b*(x[1]))


# initial guesses
i= 0.02
#j=1.2
n = 2
x0 = np.zeros(n)
x0[0] = 1.0
x0[1] = 5.0

# show initial objective
#print('Initial Objective: ' + str(objective(x0, i)))
#For j in np.arange(1.1,1.5, .1):

for i in np.arange(ub,lb, .0001):
        
    solution1 = minimize(objective,x0, i, method="Nelder-Mead")
    seed = solution1.x
    
    solution = minimize(objective,seed, i, method="Nelder-Mead")
    x = solution.x
    
    m= (x[1]-x[0])/x[1]
    
    h1 = (1/2)*(1/ x[0]**2) - (Z/ x[0])
    h2 = (1/2)*(1/ x[1]**2) - (Z/ x[1])
    #J =  (1/ math.sqrt(x[0]**2 + x[1]**2)) 
    J12=  (1/ math.sqrt(x[0]**2 + x[1]**2)) - (i*(x[0]) + i*(x[1]))
    energy = objective(x, i)
    #- (i*(x[0]) - i*(x[1]))
    #print(m)
    Norm = math.sqrt((h1)**2 + (h2)**2 + (J12)**2)
    norm_energy = (energy) / (Norm)
    m1 = h1 / (Norm)
    m2 = h2 / (Norm)
    m3 = J12 / (Norm)
    
    response = solver.sample_ising({'a': m1, 'b': m2}, {('a', 'b'): m3}, num_reads=1)
    energydwave= response.data_vectors['energy'] 
    #print(energy)
    
    m5 = energydwave
    plt.figure(1)
    plt.scatter(i, m5)
    plt.xlabel(r'$\mathcal{E}$')
    plt.ylabel(r'$Normalized ~Energy ~D-wave$')
    plt.title(r'$Normalized~ Energy ~D-wave$ vs $\mathcal{E}$')
    plt.xlim(ub,lb)
    
    m4 = norm_energy
    plt.figure(2)
    plt.scatter(i, m4)
    plt.xlabel(r'$\mathcal{E}$')
    plt.ylabel(r'$Normalized ~Energy$')
    plt.title(r'$Normalized~ Energy$ vs $\mathcal{E}$')
    plt.xlim(ub,lb)
    
    #print(m1, m2, m3, i)

# %%
import dimod
import neal
solver = neal.SimulatedAnnealingSampler()
import numpy as np
import math 
from scipy.optimize import minimize
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy.optimize import minimize, minimize_scalar
from scipy import integrate
# %matplotlib inline

Z=3
ub= 0.04
lb = 0.08

def objective(x,b):
    return (1/2)*((1/ x[0]**2)+ (1/ x[1]**2)) - Z*(1/ x[0]) - Z*(1/ x[1]) + (1/ math.sqrt(x[0]**2 + x[1]**2)) - (b*(x[0]) + b*(x[1]))


# initial guesses
i= 0.02
#j=1.2
n = 2
x0 = np.zeros(n)
x0[0] = 1.0
x0[1] = 5.0

# show initial objective
#print('Initial Objective: ' + str(objective(x0, i)))
#For j in np.arange(1.1,1.5, .1):

for i in np.arange(ub,lb, .0001):
        
    solution1 = minimize(objective,x0, i, method="Nelder-Mead")
    seed = solution1.x
    
    solution = minimize(objective,seed, i, method="Nelder-Mead")
    x = solution.x
    
    #m= (x[1]-x[0])/x[1]
    
    h1 = (1/2)*(1/ x[0]**2) - (Z/ x[0])
    h2 =(1/2)* (1/ x[1]**2) - (Z/ x[1])
    #J =  (1/ math.sqrt(x[0]**2 + x[1]**2)) 
    J12=  (1/ math.sqrt(x[0]**2 + x[1]**2)) - (i*(x[0]) + i*(x[1]))
    energy = objective(x, i)
    #- (i*(x[0]) - i*(x[1]))
    #print(m)
    Norm = math.sqrt((h1)**2 + (h2)**2 + (J12)**2)
    norm_energy = (energy) / (Norm)
    m1 = h1 / (Norm)
    m2 = h2 / (Norm)
    m3 = J12 / (Norm)
    
    response = solver.sample_ising({'a': m1, 'b': m2}, {('a', 'b'): m3}, num_reads=1)
    energydwave= response.data_vectors['energy'] 
    #print(energy)
    
    m5 = energydwave
    plt.figure(1)
    plt.scatter(i, m5)
    plt.xlabel(r'$\mathcal{E}$')
    plt.ylabel(r'$Normalized ~Energy ~D-wave$')
    plt.title(r'$Normalized~ Energy ~D-wave$ vs $\mathcal{E}$')
    plt.xlim(ub,lb)
    
    m4 = norm_energy
    plt.figure(2)
    plt.scatter(i, m4)
    plt.xlabel(r'$\mathcal{E}$')
    plt.ylabel(r'$Normalized ~Energy$')
    plt.title(r'$Normalized~ Energy$ vs $\mathcal{E}$')
    plt.xlim(ub,lb)
    
    #print(m1, m2, m3, i)
    
    #print(energydwave)

# %% [markdown]
# # 3-electon system large-D with electric field and Z=3

# %%
import dimod
import neal
import numpy as np
import math 
from scipy.optimize import minimize
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy.optimize import minimize, minimize_scalar
from scipy import integrate
# %matplotlib inline

solver = neal.SimulatedAnnealingSampler()

Z=3

def KE(x):
    return (1/2)*((1/ x[0]**2) + (1/ x[1]**2) + (4/ x[2]**2))



def PE(x):
    return (Z*(1/ x[0]) + Z*(1/ x[1]) + Z*(1/ x[2]))

def IE(x):
    return (1/ math.sqrt(x[0]**2 + x[1]**2))+ (1/ math.sqrt(x[0]**2 + x[2]**2))+ (1/ math.sqrt(x[1]**2 + x[2]**2))

def EE(x,b):
    return -2*b*(x[0]+x[1] + x[2])

def objective(x,b):
    return KE(x) - PE(x) + IE(x) + EE(x, b)


# initial guesses
i= 0.02
#j=1.2
n = 3
x0 = np.zeros(n)
x0[0] = 1.0
x0[1] = 3.0
x0[2] = 5.0

# show initial objective
#print('Initial Objective: ' + str(objective(x0, i)))
#For j in np.arange(1.1,1.5, .1):

ub= -0.03
lb = 0.03


for i in np.arange(ub,lb, .0001):
        
    solution1 = minimize(objective,x0, i, method="Nelder-Mead")
    seed = solution1.x
    
    solution = minimize(objective,seed, i, method="Nelder-Mead")
    x = solution.x
    
    m= (x[1]-x[0])/x[1]
    
    h1 = (1/2)*(1/ x[0]**2) - (Z/ x[0])
    h2 = (1/2)*(1/ x[1]**2) - (Z/ x[1])
    h3 =(1/2)* (4/ x[2]**2) - (Z/ x[2]) 
    J12 =  (1/ math.sqrt(x[0]**2 + x[1]**2)) - (i*(x[0]) + i*(x[1]))
    J13 =  (1/ math.sqrt(x[0]**2 + x[2]**2)) - (i*(x[0]) + i*(x[2]))
    J23 =  (1/ math.sqrt(x[1]**2 + x[2]**2)) - (i*(x[1]) + i*(x[2]))
    energy = objective(x, i)
    #L=  (1/ math.sqrt(x[2]**2 + x[1]**2)) - (i*(x[1]) - i*(x[2]))
    #- (i*(x[0]) - i*(x[1]))
    #print(m)
    # show final objective
    #print('Final Objective: ' + str(objective(x, i)))
    #energy = objective(x, i)
    #- (i*(x[0]) - i*(x[1]))
    #print(m)
    Norm = math.sqrt((h1)**2 + (h2)**2+ (h3)**2 + (J12)**2 + (J13)**2 + (J23)**2)
    norm_energy = (energy) / (Norm)
    m1 = h1 / (Norm)
    m2 = h2 / (Norm)
    m3 = h3/(Norm)
    m4 = J12 / (Norm)
    m5 = J13 / (Norm)
    m6 = J23 / (Norm)
    
    response = solver.sample_ising({'a': m1, 'b': m2, 'c': m3}, {('a', 'b'): m4, ('b', 'c'): m5, ('c', 'a'): m6}, num_reads=1)
    norm_energydwave= response.data_vectors['energy'] 
    #print(energy)

    
    m7 = norm_energy
    plt.figure(1)
    plt.scatter(i, m7)
    plt.xlabel(r'$\mathcal{E}$')
    plt.ylabel(r'$Normalized~energy$')
    plt.title(r'$Normalized~energy$ vs $\mathcal{E}$')
    plt.xlim(ub,lb)
    
    m8 = norm_energydwave
    plt.figure(2)
    plt.scatter(i, m8)
    plt.xlabel(r'$\mathcal{E}$')
    plt.ylabel(r'$D-Wave~Energy$')
    plt.title(r'$D-Wave ~ Energy$ vs $\mathcal{E}$')
    plt.xlim(ub,lb)
    
    #print(m1, m2, m3, m4, m5, m6, i)

# %%
import dimod
import neal
solver = neal.SimulatedAnnealingSampler()
import numpy as np
import math 
from scipy.optimize import minimize
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy.optimize import minimize, minimize_scalar
from scipy import integrate
# %matplotlib inline

Z=2
ub= -0.01
lb = 0.04

def objective(x,b):
    return (1/2)*((1/ x[0]**2)+ (1/ x[1]**2)) - Z*(1/ x[0]) - Z*(1/ x[1]) + (1/ math.sqrt(x[0]**2 + x[1]**2)) - (b*(x[0]) + b*(x[1]))


# initial guesses
i= 0.02
#j=1.2
n = 2
x0 = np.zeros(n)
x0[0] = 1.0
x0[1] = 5.0

# show initial objective
#print('Initial Objective: ' + str(objective(x0, i)))
#For j in np.arange(1.1,1.5, .1):

for i in np.arange(ub,lb, .0001):
        
    solution1 = minimize(objective,x0, i, method="Nelder-Mead")
    seed = solution1.x
    
    solution = minimize(objective,seed, i, method="Nelder-Mead")
    x = solution.x
    
    m= (x[1]-x[0])/x[1]
    
    h1 = (1/ x[0]**2) - (Z/ x[0])
    h2 = (1/ x[1]**2) - (Z/ x[1])
    #J =  (1/ math.sqrt(x[0]**2 + x[1]**2)) 
    J12=  (1/ math.sqrt(x[0]**2 + x[1]**2)) - (i*(x[0]) + i*(x[1]))
    energy = objective(x, i)
    #- (i*(x[0]) - i*(x[1]))
    #print(m)
    Norm = math.sqrt((h1)**2 + (h2)**2 + (J12)**2)
    norm_energy = (energy) / (Norm)
    m1 = h1 / (Norm)
    m2 = h2 / (Norm)
    m3 = J12 / (Norm)
    
    H1 = -(1/2)*(m1+(m3/2))
    H2 = -(1/2)*(m2+(m3/2))
    H3 =  m3/4
    I1 = (1/2)*(m1+m2+(m3/2))
    
    response = solver.sample_ising({'a': H1, 'b': H2}, {('a', 'b'): H3}, num_reads=1)
    energydwave= response.data_vectors['energy'] 
    #print(energy)
    
    print(I1, H1, H2, H3,i)
    

    
    #print(m1, m2, m3, i)
    
    #print(energydwave)
# Out:
# -0.1970804908968135 -0.004180041045188682 -0.004260707824131876 0.20552123976613407 -0.01
# -0.19714220494291684 -0.004217817024963932 -0.004149078139669582 0.20550910010755036 -0.0099
# -0.19724670311945117 -0.004094558755440542 -0.0041472782715716305 0.2054885401464633 -0.009800000000000001
# -0.1973077963106256 -0.004063789187502664 -0.004104932222709606 0.20547651772083783 -0.009700000000000002
# -0.19740818811792546 -0.003994799387603359 -0.00405376962688761 0.20545675713241643 -0.009600000000000003
# -0.19739970630970743 -0.004054908581488853 -0.004003812111944199 0.2054584270031405 -0.009500000000000003
# -0.19746017490840623 -0.004009883763354399 -0.0039764646119922475 0.20544652328375285 -0.009400000000000004
# -0.19752619395862603 -0.0039381040664826505 -0.00396922657829038 0.20543352460339903 -0.009300000000000004
# -0.19765978418782268 -0.00385057101092956 -0.003896859857596746 0.20540721505634899 -0.009200000000000005
# -0.1976566264787472 -0.0038476968688054836 -0.0039035134464564247 0.20540783679400915 -0.009100000000000006
# -0.1978122229116106 -0.003816240987123992 -0.0037487191074510595 0.20537718300618568 -0.009000000000000006
# -0.19785214335297954 -0.003797308978049002 -0.003719863934113804 0.20536931626514235 -0.008900000000000007
# -0.19792790507961502 -0.00375167598868853 -0.003674804197820819 0.20535438526612435 -0.008800000000000007
# -0.19798239831637107 -0.0036429153316455687 -0.0037183305602764005 0.205343644208293 -0.008700000000000008
# -0.19805894169257307 -0.0036631315201673953 -0.0036064818644367114 0.2053285550771772 -0.008600000000000009
# -0.25 0.25 0.25 -0.25 0.036999999999999714
# -0.25 0.25 0.25 -0.25 0.03709999999999971
# -0.25 0.25 0.25 -0.25 0.03719999999999971
# -0.25 0.25 0.25 -0.25 0.037299999999999715
# -0.25 0.25 0.25 -0.25 0.03739999999999971
# -0.25 0.25 0.25 -0.25 0.03749999999999971
# -0.25 0.25 0.25 -0.25 0.03759999999999971
# -0.25 0.25 0.25 -0.25 0.03769999999999971
# -0.25 0.25 0.25 -0.25 0.03779999999999971
# -0.25 0.25 0.25 -0.25 0.037899999999999705
# -0.25 0.25 0.25 -0.25 0.03799999999999971
# -0.25 0.25 0.25 -0.25 0.03809999999999971
# -0.25 0.25 0.25 -0.25 0.038199999999999706
# -0.25 0.25 0.25 -0.25 0.0382999999999997
# -0.25 0.25 0.25 -0.25 0.038399999999999705
# -0.25 0.25 0.25 -0.25 0.03849999999999971
# -0.25 0.25 0.25 -0.25 0.038599999999999704
# -0.25 0.25 0.25 -0.25 0.0386999999999997
# -0.25 0.25 0.25 -0.25 0.0387999999999997
# -0.25 0.25 0.25 -0.25 0.038899999999999706
# -0.25 0.25 0.25 -0.25 0.0389999999999997
# -0.25 0.25 0.25 -0.25 0.0390999999999997
# -0.25 0.25 0.25 -0.25 0.0391999999999997
# -0.25 0.25 0.25 -0.25 0.0392999999999997
# -0.25 0.25 0.25 -0.25 0.0393999999999997
# -0.25 0.25 0.25 -0.25 0.039499999999999695
# -0.25 0.25 0.25 -0.25 0.0395999999999997
# -0.25 0.25 0.25 -0.25 0.0396999999999997
# -0.25 0.25 0.25 -0.25 0.0397999999999997
# -0.25 0.25 0.25 -0.25 0.03989999999999969

# %%
import dimod
import neal
import numpy as np
import math 
from scipy.optimize import minimize
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy.optimize import minimize, minimize_scalar
from scipy import integrate
# %matplotlib inline

solver = neal.SimulatedAnnealingSampler()

Z=3

def KE(x):
    return (1/2)*((1/ x[0]**2) + (1/ x[1]**2) + (4/ x[2]**2))



def PE(x):
    return (Z*(1/ x[0]) + Z*(1/ x[1]) + Z*(1/ x[2]))

def IE(x):
    return (1/ math.sqrt(x[0]**2 + x[1]**2))+ (1/ math.sqrt(x[0]**2 + x[2]**2))+ (1/ math.sqrt(x[1]**2 + x[2]**2))

def EE(x,b):
    return -2*b*(x[0]+x[1] + x[2])

def objective(x,b):
    return KE(x) - PE(x) + IE(x) + EE(x, b)


# initial guesses
i= 0.02
#j=1.2
n = 3
x0 = np.zeros(n)
x0[0] = 1.0
x0[1] = 3.0
x0[2] = 5.0

# show initial objective
#print('Initial Objective: ' + str(objective(x0, i)))
#For j in np.arange(1.1,1.5, .1):

ub= -0.03
lb = 0.03


for i in np.arange(ub,lb, .0001):
        
    solution1 = minimize(objective,x0, i, method="Nelder-Mead")
    seed = solution1.x
    
    solution = minimize(objective,seed, i, method="Nelder-Mead")
    x = solution.x
    
    m= (x[1]-x[0])/x[1]
    
    h1 = (1/2)*(1/ x[0]**2) - (Z/ x[0])
    h2 = (1/2)*(1/ x[1]**2) - (Z/ x[1])
    h3 = (1/2)*(4/ x[2]**2) - (Z/ x[2]) 
    J12 =  (1/ math.sqrt(x[0]**2 + x[1]**2)) - (i*(x[0]) + i*(x[1]))
    J13 =  (1/ math.sqrt(x[0]**2 + x[2]**2)) - (i*(x[0]) + i*(x[2]))
    J23 =  (1/ math.sqrt(x[1]**2 + x[2]**2)) - (i*(x[1]) + i*(x[2]))
    energy = objective(x, i)
    #L=  (1/ math.sqrt(x[2]**2 + x[1]**2)) - (i*(x[1]) - i*(x[2]))
    #- (i*(x[0]) - i*(x[1]))
    #print(m)
    # show final objective
    #print('Final Objective: ' + str(objective(x, i)))
    #energy = objective(x, i)
    #- (i*(x[0]) - i*(x[1]))
    #print(m)
    Norm = math.sqrt((h1)**2 + (h2)**2+ (h3)**2 + (J12)**2 + (J13)**2 + (J23)**2)
    norm_energy = (energy) / (Norm)
    m1 = h1 / (Norm)
    m2 = h2 / (Norm)
    m3 = h3/(Norm)
    m4 = J12 / (Norm)
    m5 = J13 / (Norm)
    m6 = J23 / (Norm)
    
    I1 = (1/2)*(m1 +m2+m3+(m4/2)+(m5/2)+(m6/2))
    
    H1 = -(1/2)*(m1+(m4/2)+(m5/2))
    H2 = -(1/2)*(m2+(m4/2)+(m6/2))
    H3 = -(1/2)*(m3+(m5/2)+(m6/2))
    
    L1= (m4/4)
    L2= (m5/4)
    L3= (m6/4)
    
    response = solver.sample_ising({'a': H1, 'b': H2, 'c': H3}, {('a', 'b'): L1, ('b', 'c'): L3, ('c', 'a'): L2}, num_reads=1)
    norm_energydwave= response.data_vectors['energy'] 
    #print(energy)

    
    m7 = norm_energy
    plt.figure(1)
    plt.scatter(i, m7)
    plt.xlabel(r'$\mathcal{E}$')
    plt.ylabel(r'$Normalized~energy$')
    plt.title(r'$Normalized~energy$ vs $\mathcal{E}$')
    plt.xlim(ub,lb)
    
    m8 = I1+norm_energydwave
    plt.figure(2)
    plt.scatter(i, m8)
    plt.xlabel(r'$\mathcal{E}$')
    plt.ylabel(r'$D-Wave~Energy$')
    plt.title(r'$D-Wave ~ Energy$ vs $\mathcal{E}$')
    plt.xlim(ub,lb)
    
    #print(m1, m2, m3, m4, m5, m6, i)

# %%
import dimod
import neal
solver = neal.SimulatedAnnealingSampler()
import numpy as np
import math 
from scipy.optimize import minimize
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy.optimize import minimize, minimize_scalar
from scipy import integrate
# %matplotlib inline

Z=2
ub= -0.01
lb = 0.04

def objective(x,b):
    return (1/2)*((1/ x[0]**2)+ (1/ x[1]**2)) - Z*(1/ x[0]) - Z*(1/ x[1]) + (1/ math.sqrt(x[0]**2 + x[1]**2)) - (b*(x[0]) + b*(x[1]))


# initial guesses
i= 0.02
#j=1.2
n = 2
x0 = np.zeros(n)
x0[0] = 1.0
x0[1] = 5.0

# show initial objective
#print('Initial Objective: ' + str(objective(x0, i)))
#For j in np.arange(1.1,1.5, .1):

for i in np.arange(ub,lb, .0001):
        
    solution1 = minimize(objective,x0, i, method="Nelder-Mead")
    seed = solution1.x
    
    solution = minimize(objective,seed, i, method="Nelder-Mead")
    x = solution.x
    
    m= (x[1]-x[0])/x[1]
    
    h1 = ((1/2)*(1/ x[0]**2)) - (Z/ x[0])
    h2 = ((1/2)*(1/ x[1]**2)) - (Z/ x[1])
    #J =  (1/ math.sqrt(x[0]**2 + x[1]**2)) 
    J12=  (1/ math.sqrt(x[0]**2 + x[1]**2)) - (i*(x[0]) + i*(x[1]))
    energy = objective(x, i)
    #- (i*(x[0]) - i*(x[1]))
    #print(m)
    Norm = math.sqrt((h1)**2 + (h2)**2 + (J12)**2)
    norm_energy = (energy) / (Norm)
    m1 = h1 / (Norm)
    m2 = h2 / (Norm)
    m3 = J12 / (Norm)
    
    H1 = -(1/2)*(m1+(m3/2))
    H2 = -(1/2)*(m2+(m3/2))
    H3 =  m3/4
    I1 = (1/2)*(m1+m2+(m3/2))
    
    response = solver.sample_ising({'a': H1, 'b': H2}, {('a', 'b'): H3}, num_reads=1)
    energydwave= response.data_vectors['energy'] 
    #print(energy)
    
    m5 = I1+energydwave
    plt.figure(1)
    plt.scatter(i, m5)
    plt.xlabel(r'$\mathcal{E}$')
    plt.ylabel(r'$Normalized ~Energy ~D-wave$')
    plt.title(r'$Normalized~ Energy ~D-wave$ vs $\mathcal{E}$')
    plt.xlim(ub,lb)
    
    m4 = norm_energy
    plt.figure(2)
    plt.scatter(i, m4)
    plt.xlabel(r'$\mathcal{E}$')
    plt.ylabel(r'$Normalized ~Energy$')
    plt.title(r'$Normalized~ Energy$ vs $\mathcal{E}$')
    plt.xlim(ub,lb)
    
    #print(m1, m2, m3, i)
    
    #print(energydwave)

# %%
import numpy as np
import math 
from scipy.optimize import minimize
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy.optimize import minimize, minimize_scalar
from scipy import integrate
# %matplotlib inline


Z=1

def KE(x):
    return (1/2)*((1/ x[0]**2) + (1/ x[1]**2))* (1/(math.sin(x[4])**2))

def PE1(x,a):
    return (Z*(1/ math.sqrt(x[0]**2 + (x[2]+a)**2))) + (Z*(1/ math.sqrt(x[0]**2 + (x[2]-a)**2)))

def PE2(x,a):
    return (Z*(1/ math.sqrt(x[1]**2 + (x[3]+a)**2))) + (Z*(1/ math.sqrt(x[1]**2 + (x[3]-a)**2)))

def IE(x):
    return 1/ math.sqrt((x[2]-x[3])**2 + x[0]**2 + x[1]**2 - 2*x[0]*x[1]*(math.cos(x[4])))


def objective(x,a):
    return KE(x) - PE1(x,a) - PE2(x,a) + IE(x)


# initial guesses
#i= 0.02
#j=1.2
n = 5
x0 = np.zeros(n)
x0[0] = 1.0
x0[1] = 2.0
x0[2] = 3.0                                                       
x0[3] = 4.0
x0[4] = 5.0
                                                       
# show initial objective
#print('Initial Objective: ' + str(objective(x0, i)))
#For j in np.arange(1.1,1.5, .1):

ub= 0.0
lb = 6.0


for i in np.arange(ub,lb, 0.5):
        
    solution1 = minimize(objective,x0, i, method="Nelder-Mead")
    seed = solution1.x
    
    solution = minimize(objective,seed, i, method="Nelder-Mead")
    x = solution.x
    
    #m= (x[1]-x[0])/x[1]
    
    h1 = (1/2)*((1/ x[0]**2)* (1/(math.sin(x[4])**2))) - (Z*(1/ math.sqrt(x[0]**2 + (x[2]+i)**2))) - (Z*(1/ math.sqrt(x[0]**2 + (x[2]-i)**2)))
    #h1 = (1/2)*((1/ x[0]**2)* (1/(math.sin(x[4])**2)) - (Z*(1/ math.sqrt(x[0]**2 + (x[2]+i)**2))) + (Z*(1/ math.sqrt(x[0]**2 + (x[2]-a)**2)))
    h2 = (1/2)*((1/ x[1]**2)* (1/(math.sin(x[4])**2))) - (Z*(1/ math.sqrt(x[1]**2 + (x[3]+i)**2))) - (Z*(1/ math.sqrt(x[1]**2 + (x[3]-i)**2)))
    #h2 = (1/2)*((1/ x[0]**2)* (1/(math.sin(x[4])**2)) - (Z*(1/ math.sqrt(x[0]**2 + (x[2]+i)**2))) + (Z*(1/ math.sqrt(x[0]**2 + (x[2]-a)**2)))
                                              
    J12 =  1/ math.sqrt((x[2]-x[3])**2 + x[0]**2 + x[1]**2 - 2*x[0]*x[1]*(math.cos(x[4])))
    energy = objective(x, i)


    m1 = h1
    plt.figure(1)
    plt.scatter(i, m1)
    plt.xlabel('a')
    plt.ylabel(r'$h_{1}$')
    plt.title(r'$h_{1}$ vs z')
    #plt.title(r'$critical ~ prameter$')
    
    m2 = h2
    plt.figure(2)
    plt.scatter(i, m2)
    plt.xlabel('a')
    plt.ylabel(r'$h_{2}$')
    plt.title(r'$h_{2}$ vs a')
    #plt.title(r'$critical ~ prameter$')
    
    m3 = J12
    plt.figure(3)
    plt.scatter(i, m3)
    plt.xlabel('a')
    plt.ylabel(r'$J_{12}$')
    plt.title(r'$J_{12}$ vs a')
    #plt.title(r'$critical ~ prameter$')
    
    
    
    plt.figure(4)
    plt.scatter(i, energy)
    plt.xlabel('a')
    plt.ylabel(r'energy')
    #plt.title(r'$h_{11}$ vs z')
    #plt.title(r'$critical ~ prameter$')
